# %%
import numpy as np
from enum import Enum
from matplotlib import pyplot as pp
import random
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, plot_confusion_matrix

import sys
from tensorflow.keras.optimizers import SGD, Adam
import sklearn.metrics

# %%
dataset1 = pd.read_csv('dataI.csv',sep=';')

X1=dataset1.iloc[:,3:-1]
Y1=np.ravel(dataset1.label)

X1_train, X1_test, Y1_train, Y1_test = train_test_split(X1, Y1, random_state=23)

# Define the scaler 
scaler1 = StandardScaler().fit(X1_train)

# Scale the train and test sets
X1_train = scaler1.transform(X1_train)
X1_test = scaler1.transform(X1_test)

print(X1_train.shape)
print(X1_test.shape)
print(Y1_train.shape)
print(Y1_test.shape)
# Out:
# (15000, 200)
# (5000, 200)
# (15000,)
# (5000,)

# %%
dataset2=pd.read_csv("dataII.csv",sep=";")

X2=dataset2.iloc[:,4:-1]
Y2=np.ravel(dataset2.label)

X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2, Y2, random_state=23)

# Define the scaler 
scaler2 = StandardScaler().fit(X2_train)

# Scale the train and test sets
X2_train = scaler2.transform(X2_train)
X2_test = scaler2.transform(X2_test)

print(X2_train.shape)
print(X2_test.shape)
print(Y2_train.shape)
print(Y2_test.shape)
# Out:
# (15000, 200)
# (5000, 200)
# (15000,)
# (5000,)

# %%
X=np.concatenate((X1,X2),axis=0)
Y=np.concatenate((Y1,Y2),axis=0)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=23)

# Define the scaler 
scaler = StandardScaler().fit(X_train)

# Scale the train and test sets
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (30000, 200)
# (10000, 200)
# (30000,)
# (10000,)

# %%
E=np.arange(0+0.5,100+0.5,0.5)
eta=-1
plt.figure(figsize=(8,6))
plt.title(r"|f(E)|^2; $\eta=$"+str(eta))
for lbd in (np.arange(200,1200,200)):
    gam1=100
    plt.plot(E,np.abs(f1(E,eta,lbd,gam1))**2,
            label=r'$\Lambda_{bg}$='+str(lbd)+r" [MeV], $\gamma=$"+str(gam1)+" MeV")
    plt.legend()

plt.show()
eta=-1
plt.figure(figsize=(8,6))
plt.title(r"|f(E)|^2; $\eta=$"+str(eta))
for lbd in (np.arange(200,1200,200)):
    gam2=(-10-0.9*lbd)
    plt.plot(E,np.abs(f1(E,eta,lbd,gam2))**2,label=r'$\Lambda_{bg}$='+str(lbd)+r" [MeV], $\gamma=$"+str(gam2)+" MeV")
    plt.legend()

plt.show()
eta=-1
plt.figure(figsize=(8,6))
plt.title(r"|f(E)|^2; $\eta=$"+str(eta))
for lbd in (np.arange(200,1200,200)):
    alpha2=200
    beta2=60
    plt.plot(E,np.abs(f2(E,eta,lbd,alpha2,beta2))**2,
            label=r'$\Lambda_{bg}$='+str(lbd)+r" [MeV], $\alpha=$"+str(alpha2)+r" MeV, $\beta=$"+str(beta2))
    plt.legend()

plt.show()
E=np.arange(0+0.5,100+0.5,0.5)
eta=-1
plt.figure(figsize=(8,6))
plt.title(r"|f(E)|^2; $\eta=$"+str(eta))
for lbd in (np.arange(200,1200,200)):
    alpha2=60
    beta2=100
    plt.plot(E,np.abs(f2(E,eta,lbd,alpha2,beta2))**2,
            label=r'$\Lambda_{bg}$='+str(lbd)+r" [MeV], $\alpha=$"+str(alpha2)+r" MeV, $\beta=$"+str(beta2))
    plt.legend()

plt.show()

# %%
model = tf.keras.Sequential([
    tf.keras.Input(shape=(200,)),
    tf.keras.layers.Dense(100, activation='relu'),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])
print(model.output_shape)
model.summary()
# Out:
# (None, 1)
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_7 (Dense)              (None, 10)                1010
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 21,121
# Trainable params: 21,121
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.Adam(#learning_rate=0.8)
                        )

model.compile(loss='binary_crossentropy',
              optimizer=opt,
              metrics=['accuracy'])

# %%
model.fit(X1_train, Y1_train, epochs=8, shuffle=True)
# Out:
# Epoch 1/8
# 469/469 [==============================] - 1s 2ms/step - loss: 31807.0156 - accuracy: 0.8790
# Epoch 2/8
# 469/469 [==============================] - 1s 3ms/step - loss: 25240.7871 - accuracy: 0.8465
# Epoch 3/8
# 469/469 [==============================] - 1s 2ms/step - loss: 20606.9434 - accuracy: 0.8257
# Epoch 4/8
# 469/469 [==============================] - 1s 2ms/step - loss: 16590.4297 - accuracy: 0.8159
# Epoch 5/8
# 469/469 [==============================] - 1s 3ms/step - loss: 13426.1816 - accuracy: 0.8110
# Epoch 6/8
# 469/469 [==============================] - 1s 3ms/step - loss: 10904.5596 - accuracy: 0.8249
# Epoch 7/8
# 469/469 [==============================] - 1s 3ms/step - loss: 8848.0869 - accuracy: 0.8219
# Epoch 8/8
# 469/469 [==============================] - 1s 3ms/step - loss: 7282.7788 - accuracy: 0.8154

# %%
score = model.evaluate(X1_test, Y1_test)
print(score)
print(model.metrics_names)
# Out:
# 157/157 [==============================] - 0s 2ms/step - loss: 6529.7554 - accuracy: 0.8036
# [6529.75537109375, 0.803600013256073]
# ['loss', 'accuracy']

# %%
resultados = np.around(model.predict(X_test))

# %%
cm = confusion_matrix(Y_test, resultados, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap= 'Blues')

# %%
cm = confusion_matrix(Y_test, resultados, normalize=None)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap= 'Reds')
