# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

values=pd.read_csv("dataII.csv",sep=";")
X=values.iloc[:,4:-1]
Y=np.ravel(values.label)

def tempMap(Y):
    return np.where(Y==2,0,1)

def tempUnmap(Y):
    return np.where(Y==0,2,1)

Y_temp=tempMap(Y)

X_train, X_test, Y_train, Y_test = train_test_split(X, Y_temp, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (150000, 200)
# (50000, 200)
# (150000,)
# (50000,)

# %%
scaler = StandardScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Sequential()

model.add(Dense(200, activation='relu', input_shape=(200,)))
model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
#print(model.output_shape)

model.summary()

#model.get_config()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 200)               40200
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 101
# ...
# Total params: 60,401
# Trainable params: 60,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
                   
model.fit(X_train, Y_train, epochs=12, verbose=1)
# Out:
# Epoch 1/12
# 4688/4688 [==============================] - 15s 3ms/step - loss: 0.3244 - accuracy: 0.8509
# Epoch 2/12
# 4688/4688 [==============================] - 14s 3ms/step - loss: 0.2240 - accuracy: 0.8985
# Epoch 3/12
# 4688/4688 [==============================] - 14s 3ms/step - loss: 0.1877 - accuracy: 0.9151
# Epoch 4/12
# 4688/4688 [==============================] - 14s 3ms/step - loss: 0.1700 - accuracy: 0.9224
# Epoch 5/12
# 4688/4688 [==============================] - 14s 3ms/step - loss: 0.1519 - accuracy: 0.9305
# Epoch 6/12
# 4688/4688 [==============================] - 14s 3ms/step - loss: 0.1391 - accuracy: 0.9355
# Epoch 7/12
# 4688/4688 [==============================] - 15s 3ms/step - loss: 0.1328 - accuracy: 0.9391
# Epoch 8/12
# 4688/4688 [==============================] - 14s 3ms/step - loss: 0.1235 - accuracy: 0.9427
# Epoch 9/12
# 4688/4688 [==============================] - 14s 3ms/step - loss: 0.1164 - accuracy: 0.9464
# Epoch 10/12
# ...

# %%
score = model.evaluate(X_test, Y_test, verbose=1)

print(model.metrics_names)
print(score)
# Out:
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.1128 - accuracy: 0.9506
# ['loss', 'accuracy']
# [0.11284618824720383, 0.9505599737167358]

# %%
values.head
# Out:
# <bound method NDFrame.head of         eta       Lbd_bg       alpha        beta       0.5       1.0  \
# 0        -4  1051.596773   61.324266  195.062587  0.000030  0.000030
# 1        -4  1051.596773   61.324266  103.062049  0.000109  0.000107
# 2        -4  1051.596773   61.324266   61.577850  0.000161  0.000163
# 3        -4  1051.596773   61.324266  183.252853  0.000036  0.000035
# 4        -4  1051.596773   61.324266  172.714168  0.000041  0.000041
# ...     ...          ...         ...         ...       ...       ...
# 199995    0   962.101639  161.560646  196.567097  0.000037  0.000037
# 199996    0   962.101639  161.560646  152.722686  0.000038  0.000038
# 199997    0   962.101639  161.560646   98.617900  0.000031  0.000031
# 199998    0   962.101639  161.560646   54.286310  0.000014  0.000015
# 199999    0   962.101639  161.560646  134.397718  0.000037  0.000037
#
#              1.5       2.0       2.5       3.0  ...      96.0      96.5  \
# ...
