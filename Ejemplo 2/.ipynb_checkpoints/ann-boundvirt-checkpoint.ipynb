# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

values=pd.read_csv("dataI.csv",sep=";")
X=values.iloc[:,3:-1]
Y=np.ravel(values.label)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=42)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (150000, 200)
# (50000, 200)
# (150000,)
# (50000,)

# %%
scaler = StandardScaler().fit(X_train)

X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %%
model = Sequential()

model.add(Dense(200, activation='relu', input_shape=(200,)))
#model.add(Dense(100, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
#print(model.output_shape)

model.summary()

#model.get_config()
# Out:
# (None, 1)
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 200)               40200
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 201
# =================================================================
# Total params: 40,401
# Trainable params: 40,401
# Non-trainable params: 0
# _________________________________________________________________
# {'name': 'sequential',
#  'layers': [{'class_name': 'InputLayer',
#    'config': {'batch_input_shape': (None, 200),
#     'dtype': 'float32',
#     'sparse': False,
#     'ragged': False,
#     'name': 'dense_input'}},
#   {'class_name': 'Dense',
#    'config': {'name': 'dense',
#     'trainable': True,
#     'batch_input_shape': (None, 200),
#     'dtype': 'float32',
#     'units': 200,
#     'activation': 'relu',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}},
#   {'class_name': 'Dense',
#    'config': {'name': 'dense_1',
#     'trainable': True,
#     'dtype': 'float32',
#     'units': 1,
#     'activation': 'sigmoid',
#     'use_bias': True,
#     'kernel_initializer': {'class_name': 'GlorotUniform',
#      'config': {'seed': None}},
#     'bias_initializer': {'class_name': 'Zeros', 'config': {}},
#     'kernel_regularizer': None,
#     'bias_regularizer': None,
#     'activity_regularizer': None,
#     'kernel_constraint': None,
#     'bias_constraint': None}}]}

# %%
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
                   
model.fit(X_train, Y_train, epochs=8, verbose=1)
# Out:
# Epoch 1/8
# 4688/4688 [==============================] - 14s 3ms/step - loss: 0.1110 - accuracy: 0.9509
# Epoch 2/8
# 4688/4688 [==============================] - 13s 3ms/step - loss: 0.0456 - accuracy: 0.9846
# Epoch 3/8
# 4688/4688 [==============================] - 13s 3ms/step - loss: 0.0381 - accuracy: 0.9869
# Epoch 4/8
# 4688/4688 [==============================] - 13s 3ms/step - loss: 0.0309 - accuracy: 0.9895
# Epoch 5/8
# 4688/4688 [==============================] - 13s 3ms/step - loss: 0.0287 - accuracy: 0.9897
# Epoch 6/8
# 4688/4688 [==============================] - 13s 3ms/step - loss: 0.0253 - accuracy: 0.9912
# Epoch 7/8
# 4688/4688 [==============================] - 13s 3ms/step - loss: 0.0227 - accuracy: 0.9924
# Epoch 8/8
# 4688/4688 [==============================] - 13s 3ms/step - loss: 0.0192 - accuracy: 0.9931

# %%
score = model.evaluate(X_test, Y_test, verbose=1)

print(model.metrics_names)
print(score)
# Out:
# 1563/1563 [==============================] - 3s 2ms/step - loss: 0.0133 - accuracy: 0.9954
# ['loss', 'accuracy']
# [0.013277961872518063, 0.9954400062561035]
